# %%
import pandas as pd

# %%
df_emotion = pd.read_csv('/content/Lyric_AudioFeatures_Emotions_23_02.csv', engine = 'python')
df_songs = pd.read_excel('/content/BillBoard_API_spotify_with_Features_LargeDF.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df_emotion.head()
# Out:
#    Unnamed: 0  title  ... anticipation Overall_Emotion
# 0           0      0  ...     0.021739             joy
# 1           1      1  ...     0.151163    anticipation
# 2           2      2  ...     0.022222            fear
# 3           3      3  ...     0.100000             joy
# 4           4      4  ...     0.454545    anticipation
#
# [5 rows x 32 columns]

# %%
df_songs.tail()
# Out:
#            0                      1  ... duration_ms    YEAR
# 10236  15002        Champagne Night  ...      185070  2020.0
# 10237  15003             Happy Does  ...      168733  2020.0
# 10238  15004  Throat Baby (Go Baby)  ...      211610  2020.0
# 10239  15006              La Toxica  ...      180520  2020.0
# 10240  15008    Wine, Beer, Whiskey  ...      196160  2020.0
#
# [5 rows x 19 columns]

# %%
df_songs.rename(columns = {5:'id', 2:'artist'}, inplace = True)
df_songs.head()
# Out:
#    0                              1  ... duration_ms    YEAR
# 0  0                Please Don't Go  ...      230533  1980.0
# 1  1  Escape (The Pina Colada Song)  ...      276493  1980.0
# 2  2                  Rock With You  ...      220627  1980.0
# 3  3             Send One Your Love  ...      242333  1980.0
# 4  4    Do That To Me One More Time  ...      256667  1980.0
#
# [5 rows x 19 columns]

# %%
mergedf = df_songs.merge(df_emotion,on = 'id', how='inner')
print('Merged data frame:')
display(mergedf)
# Out:
# Merged data frame:
#            0                              1  ... anticipation  Overall_Emotion
# 0          0                Please Don't Go  ...     0.021739              joy
# 1          1  Escape (The Pina Colada Song)  ...     0.151163     anticipation
# 2          2                  Rock With You  ...     0.022222             fear
# 3          3             Send One Your Love  ...     0.100000              joy
# 4          4    Do That To Me One More Time  ...     0.454545     anticipation
# ...      ...                            ...  ...          ...              ...
# 10088  15002                Champagne Night  ...     0.141026              joy
# 10089  15003                     Happy Does  ...     0.141243              joy
# 10090  15004          Throat Baby (Go Baby)  ...     0.074689              joy
# 10091  15006                      La Toxica  ...          NaN             fear
# 10092  15008            Wine, Beer, Whiskey  ...     0.015873              joy
#
# ...

# %%
mergedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10093 entries, 0 to 10092
# Data columns (total 50 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   0                   10093 non-null  int64
#  1   1                   10093 non-null  object
#  2   artist_x            10093 non-null  object
#  3   3                   10093 non-null  int64
#  4   4                   10093 non-null  object
#  5   id                  10093 non-null  object
#  6   danceability_x      10093 non-null  float64
#  7   energy_x            10093 non-null  float64
#  8   key_x               10093 non-null  int64
#  9   loudness_x          10093 non-null  float64
#  10  mode_x              10093 non-null  int64
#  11  speechiness_x       10093 non-null  float64
#  12  acousticness_x      10093 non-null  float64
#  13  instrumentalness_x  10093 non-null  float64
#  14  liveness_x          10093 non-null  float64
# ...

# %%
del mergedf[0]
del mergedf[3]
del mergedf['danceability_x']
del mergedf['energy_y']
del mergedf['key_y']
del mergedf['loudness_y']
del mergedf['mode_y']
del mergedf['speechiness_y']
del mergedf['acousticness_y']
del mergedf['instrumentalness_y']
del mergedf['liveness_y']
del mergedf['valence_y']
del mergedf['tempo_y']
del mergedf['duration_ms_y']
del mergedf['Unnamed: 0']
del mergedf['title']

# %%
mergedf.tail()
# Out:
#                            1         artist_x  ... anticipation Overall_Emotion
# 10088        Champagne Night           Lady A  ...     0.141026             joy
# 10089             Happy Does    Kenny Chesney  ...     0.141243             joy
# 10090  Throat Baby (Go Baby)         BRS Kash  ...     0.074689             joy
# 10091              La Toxica          Farruko  ...          NaN            fear
# 10092    Wine, Beer, Whiskey  Little Big Town  ...     0.015873             joy
#
# [5 rows x 34 columns]

# %%
mergedf.rename(columns = {1:'track', 'artist_x': 'artist', 4:'wrong_date', 'energy_x':'energy', 'key_x':'key', 'loudness_x': 'loudness', 'mode_x':'mode', 'speechiness_x': 'speechiness', 'acousticness_x': 'acousticness', 'instrumentalness_x': 'instrumentalness', 'liveness_x': 'liveness', 'valence_x': 'valence', 'tempo_x': 'tempo', 'duration_ms_x': 'duration_ms', 'danceability_y': 'danceability'}, inplace = True)

# %%
mergedf.head()
# Out:
#                                1  ... Overall_Emotion
# 0                Please Don't Go  ...             joy
# 1  Escape (The Pina Colada Song)  ...    anticipation
# 2                  Rock With You  ...            fear
# 3             Send One Your Love  ...             joy
# 4    Do That To Me One More Time  ...    anticipation
#
# [5 rows x 34 columns]

# %%
mergedf.to_csv('Full_Features_24_02.csv', header = True)
